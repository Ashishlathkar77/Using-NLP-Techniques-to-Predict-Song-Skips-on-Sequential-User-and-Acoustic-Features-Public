# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
track_features = pd.read_csv('/content/processed_tf.csv')
sessions_data = pd.read_csv('/content/processed_sessions.csv')

# %%
track_features
# Out:
#        Unnamed: 0                                track_id    duration  \
# 0               0  t_a540e552-16d4-42f8-a185-232bd650ea7d  109.706673
# 1               1  t_67965da0-132b-4b1e-8a69-0ef99b32287c  187.693329
# 2               2  t_0614ecd3-a7d5-40a1-816e-156d5872a467  160.839996
# 3               3  t_070a63a0-744a-434e-9913-a97b02926a29  175.399994
# 4               4  t_d6990e17-9c31-4b01-8559-47d9ce476df1  350.166664
# ...           ...                                     ...         ...
# 50699       50699  t_402930af-4174-47ec-b1fd-593d93597624  184.686798
# 50700       50700  t_e5f9a069-a893-452e-ab21-49b4eaebfbd0  251.813324
# 50701       50701  t_3983306d-13b4-4027-9391-7236ca93d2bf  157.520004
# 50702       50702  t_74eb6e99-210b-440c-8d7b-4db6617d1c80  129.105392
# 50703       50703  t_aec0dda3-19b4-4222-be07-327c12f21456  213.689392
#
#        us_popularity_estimate  acousticness  beat_strength  bounciness  \
# ...

# %%
track_features.drop(columns = 'Unnamed: 0', axis = 1, inplace = True)
track_features.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50704 entries, 0 to 50703
# Data columns (total 29 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   track_id                50704 non-null  object
#  1   duration                50704 non-null  float64
#  2   us_popularity_estimate  50704 non-null  float64
#  3   acousticness            50704 non-null  float64
#  4   beat_strength           50704 non-null  float64
#  5   bounciness              50704 non-null  float64
#  6   danceability            50704 non-null  float64
#  7   dyn_range_mean          50704 non-null  float64
#  8   energy                  50704 non-null  float64
#  9   flatness                50704 non-null  float64
#  10  instrumentalness        50704 non-null  float64
#  11  key                     50704 non-null  int64
#  12  liveness                50704 non-null  float64
#  13  loudness                50704 non-null  float64
# ...

# %%
sessions_data
# Out:
#         Unnamed: 0  session_position  session_length  \
# 0                0                 1              20
# 1                1                 2              20
# 2                2                 3              20
# 3                3                 4              20
# 4                4                 5              20
# ...            ...               ...             ...
# 167875      167875                16              20
# 167876      167876                17              20
# 167877      167877                18              20
# 167878      167878                19              20
# 167879      167879                20              20
#
#                                 track_id_clean  context_switch  \
# 0       t_0479f24c-27d2-46d6-a00c-7ec928f2b539               0
# 1       t_9099cd7b-c238-47b7-9381-f23f2c1d1043               0
# 2       t_fc5df5ba-5396-49a7-8b29-35d0d28249e0               0
# 3       t_23cff8d6-d874-4b20-83dc-94e450e8aa20               0
# ...

# %%
sessions_data.drop(columns = 'Unnamed: 0', axis = 1, inplace = True)
sessions_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 167880 entries, 0 to 167879
# Data columns (total 16 columns):
#  #   Column                           Non-Null Count   Dtype
# ---  ------                           --------------   -----
#  0   session_position                 167880 non-null  int64
#  1   session_length                   167880 non-null  int64
#  2   track_id_clean                   167880 non-null  object
#  3   context_switch                   167880 non-null  int64
#  4   no_pause_before_play             167880 non-null  int64
#  5   short_pause_before_play          167880 non-null  int64
#  6   long_pause_before_play           167880 non-null  int64
#  7   hist_user_behavior_n_seekfwd     167880 non-null  int64
#  8   hist_user_behavior_n_seekback    167880 non-null  int64
#  9   hist_user_behavior_is_shuffle    167880 non-null  int64
#  10  hour_of_day                      167880 non-null  int64
#  11  premium                          167880 non-null  int64
# ...

# %%
sessions_data = sessions_data.rename(columns = {'track_id_clean' : 'track_id'})

# %%
sessions_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 167880 entries, 0 to 167879
# Data columns (total 16 columns):
#  #   Column                           Non-Null Count   Dtype
# ---  ------                           --------------   -----
#  0   session_position                 167880 non-null  int64
#  1   session_length                   167880 non-null  int64
#  2   track_id                         167880 non-null  object
#  3   context_switch                   167880 non-null  int64
#  4   no_pause_before_play             167880 non-null  int64
#  5   short_pause_before_play          167880 non-null  int64
#  6   long_pause_before_play           167880 non-null  int64
#  7   hist_user_behavior_n_seekfwd     167880 non-null  int64
#  8   hist_user_behavior_n_seekback    167880 non-null  int64
#  9   hist_user_behavior_is_shuffle    167880 non-null  int64
#  10  hour_of_day                      167880 non-null  int64
#  11  premium                          167880 non-null  int64
# ...

# %%
data = sessions_data.merge(track_features, on = 'track_id')
data
# Out:
#         session_position  session_length  \
# 0                      1              20
# 1                      7              12
# 2                      6              20
# 3                      9              13
# 4                      7              12
# ...                  ...             ...
# 167875                 8              20
# 167876                10              20
# 167877                16              20
# 167878                17              20
# 167879                20              20
#
#                                       track_id  context_switch  \
# 0       t_0479f24c-27d2-46d6-a00c-7ec928f2b539               0
# 1       t_0479f24c-27d2-46d6-a00c-7ec928f2b539               0
# 2       t_0479f24c-27d2-46d6-a00c-7ec928f2b539               0
# 3       t_0479f24c-27d2-46d6-a00c-7ec928f2b539               0
# 4       t_0479f24c-27d2-46d6-a00c-7ec928f2b539               0
# ...                                        ...             ...
# ...

# %%
data.isnull().sum()
# Out:
# session_position                   0
# session_length                     0
# track_id                           0
# context_switch                     0
# no_pause_before_play               0
# short_pause_before_play            0
# long_pause_before_play             0
# hist_user_behavior_n_seekfwd       0
# hist_user_behavior_n_seekback      0
# hist_user_behavior_is_shuffle      0
# hour_of_day                        0
# premium                            0
# context_type                       0
# hist_user_behavior_reason_start    0
# hist_user_behavior_reason_end      0
# skipped                            0
# duration                           0
# us_popularity_estimate             0
# acousticness                       0
# beat_strength                      0
# bounciness                         0
# danceability                       0
# dyn_range_mean                     0
# energy                             0
# flatness                           0
# ...

# %%
data.duplicated().sum()
# Out:
# 433

# %%
data['track_id'].duplicated().sum()
# Out:
# 117176

# %%
data.drop_duplicates(subset = ['track_id'], keep = False, inplace = True)

# %%
data['track_id'].duplicated().sum()
# Out:
# 0

# %%
data
# Out:
#         session_position  session_length  \
# 540                    8              20
# 736                   17              20
# 826                    1              20
# 827                    2              20
# 845                    4              20
# ...                  ...             ...
# 167875                 8              20
# 167876                10              20
# 167877                16              20
# 167878                17              20
# 167879                20              20
#
#                                       track_id  context_switch  \
# 540     t_0be6eced-f56f-48bd-8086-f2e0b760fdee               0
# 736     t_bff5b6c6-6968-41be-b723-7e860b372975               0
# 826     t_e975c3a1-6a6c-4955-8bc7-02eb8e701bec               0
# 827     t_0632570b-b4b4-4c3c-b47c-443ec9fbaa11               0
# 845     t_981c30c6-7f94-4b81-b4f1-9992dae4f6a3               0
# ...                                        ...             ...
# ...

# %%
data.isnull().sum()
# Out:
# session_position                   0
# session_length                     0
# track_id                           0
# context_switch                     0
# no_pause_before_play               0
# short_pause_before_play            0
# long_pause_before_play             0
# hist_user_behavior_n_seekfwd       0
# hist_user_behavior_n_seekback      0
# hist_user_behavior_is_shuffle      0
# hour_of_day                        0
# premium                            0
# context_type                       0
# hist_user_behavior_reason_start    0
# hist_user_behavior_reason_end      0
# skipped                            0
# duration                           0
# us_popularity_estimate             0
# acousticness                       0
# beat_strength                      0
# bounciness                         0
# danceability                       0
# dyn_range_mean                     0
# energy                             0
# flatness                           0
# ...
